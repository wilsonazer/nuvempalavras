# %%
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import PlaintextCorpusReader
from matplotlib.colors import ListedColormap
from nltk.corpus import stopwords
from wordcloud import WordCloud

# %%
corpus  = PlaintextCorpusReader('legiao', '.*')

# %%
stop = stopwords.words('portuguese')
stop.extend(['dá','pra','vou','ser','vai','usa','ter','tão','mim'])

# %%
mapa = ListedColormap(['black', 'yellow', 'green', 'magenta', 'orange', 'red'])

# %%
nuvem = WordCloud( stopwords= stop,
                   background_color = 'white',
                   colormap = mapa,
                   max_words = 100
                   
        )

# %%
todas_musicas = corpus.raw()

# %%
nuvem = nuvem.generate( todas_musicas )

plt.figure( figsize=(12,8))
plt.imshow(nuvem, interpolation="bilinear")
plt.axis("off");
plt.show()
